# %%
###############################################################################
# Import packages
###############################################################################
import os
import time
import random 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mglearn
from scipy.spatial.distance import cdist
import gurobipy as gp
from gurobipy import GRB
from scipy.stats import skew
import math
import itertools
from sklearn.cluster import DBSCAN

# Load functions
from helperfunctions_data_generation import generate_cvrp_instance, distance, fun_convert_time, fun_save_file
from helperfunctions_data_generation import fun_shapley_value, solve_cvrp, plot_instance
from helperfunctions_data_generation import fun_multi_dbscan, fun_cluster_features

# %%
###############################################################################
# Generate random instances - settings
###############################################################################
num_customers_list = [6]#, 7, 8, 9] # All possible instance sizes (number of customers for an instance)
start_value = 1 # <- Der Wert hier wird als Instanz_id reingeschrieben, hab das drin weil ich immer mehrere Skripte Parallel laufen lasse, da können nicht alle bei 0 starten
number_of_instances_per_size = 1 # Determines the number of instances that are generated for each instance size (number of customers)
prints = True # Show prints and interim results during generating

# Define the range for X and Y coordinates
x_range = (0, 100)
y_range = (0, 100)
capacity_min = 10
capacity_max = 18
demand_min = 1
demand_max = 5
df_final = pd.DataFrame()
run_time = {}

###############################################################################
# START GENERAITING
###############################################################################
for num_customers in num_customers_list:
    instance_id = 100000 * num_customers * start_value # -> Random gesetzt, hauptsache es gibt bei Parallelisierung keine Überschneidung der Indizes
    start = time.time() # Start time count
    if (number_of_instances_per_size > 1): prints = False # No prints for more than one instance

    for inumber in range(0, number_of_instances_per_size):
        ###############################################################################
        # Generate a random instance
        ###############################################################################

        # Generate instance
        instance_df = generate_cvrp_instance(num_customers, x_range, y_range, demand_min, demand_max, capacity_min, capacity_max)

        # Add instance id as to each row as first column and update instance id for next iteration
        instance_df.insert(0, 'Instance ID', instance_id)
        instance_id += 1

        # Add number of customers as second feature
        instance_df.insert(1, 'Number Customers', num_customers)

        # Add 'X Depot' and 'Y Depot' columns with depot coordinates
        x_depot = instance_df.loc[0, 'X'] # X coordinate of depot
        y_depot = instance_df.loc[0, 'Y'] # Y coordinate of depot
        instance_df['X Depot'] = x_depot
        instance_df['Y Depot'] = y_depot

        if (prints == True): print('############### INSTANCE ###############'); display(instance_df)

        ###############################################################################
        # Add distance features
        ###############################################################################

        # Calculate the distance between the depot and each location
        instance_df['Depot Distance'] = np.sqrt((instance_df['X'] - x_depot) ** 2 + (instance_df['Y'] - y_depot) ** 2) # Euclidean distance

        # Calculate distances from each customer to all other customers (excluding depot) - customer distances matrix
        customer_distances = cdist(instance_df.iloc[1:][['X', 'Y']], instance_df.iloc[1:][['X', 'Y']], metric='euclidean')

        # Replace diagonal values with np.nan; otherwise the customer will be his own closest customer
        np.fill_diagonal(customer_distances, np.nan)

        # Create an array with indices of all customers and loop over each of them (excluding the depot)
        all_customers = np.arange(start=1, stop=num_customers+1)
        for i, customer in enumerate(all_customers): # i starts with zero, customer starts with one

            # Sort the distances for the current customer
            sorted_distances = np.sort(customer_distances[i])

            # Add columns for the distances to the closest, second closest, third closest, and fourth closest customers and add the respective values of the customer
            instance_df.loc[customer, 'Closest Customer Distance (CCD)'] = sorted_distances[0]
            instance_df.loc[customer, '2nd CCD'] = sorted_distances[1]
            instance_df.loc[customer, '3rd CCD'] = sorted_distances[2]
            instance_df.loc[customer, '4th CCD'] = sorted_distances[3]
            instance_df.loc[customer, '5th CCD'] = sorted_distances[4]
            instance_df.loc[customer, '6th CCD'] = sorted_distances[5] if (num_customers >= 7) else 100000
            instance_df.loc[customer, '7th CCD'] = sorted_distances[6] if (num_customers >= 8) else 100000
            instance_df.loc[customer, '8th CCD'] = sorted_distances[7] if (num_customers >= 9) else 100000
            instance_df.loc[customer, '9th CCD'] = sorted_distances[8] if (num_customers >= 10) else 100000
            instance_df.loc[customer, '10th CCD'] = sorted_distances[9] if (num_customers >= 11) else 100000

        # Calculate the mean distance to other customers
        customer_distances = pd.DataFrame(customer_distances, index=all_customers, columns=all_customers)
        mean_distances = customer_distances.mean(axis=1, skipna=True) # Calculate mean for each row over all columns, ignoring the np.nan

        # Add the 'Mean distance to other customers' column to the DataFrame (We add a NaN value for the depot since it doesn't have a mean distance)
        instance_df['Mean Distance To Other Customers'] = [np.nan] + mean_distances.tolist()
        
        # Calculate for each customer the distance to centroid of all customrs (excluding the depot) and save it in a new column
        centroid_x = instance_df.loc[1:, 'X'].mean()
        centroid_y = instance_df.loc[1:, 'Y'].mean()
        instance_df['Gravity Center Distance'] = np.sqrt((instance_df.loc[1:, 'X'] - centroid_x) ** 2 + (instance_df.loc[1:, 'Y'] - centroid_y) ** 2)
        
        if (prints == True):
            print('\n############### DISTANCE FEATURES ###############')
            print('Customer distances:'); display(customer_distances, instance_df)
        
        ###############################################################################
        # Add cluster features
        ###############################################################################

        # Cluster customers (without depot)
        # Get X and Y coordinates of the customers (excluding the depot)
        X = instance_df[['X', 'Y']][1:]

        # Clustering the customers of the instance
        assignments, core_point_indices = fun_multi_dbscan(X=X, num_customers=num_customers, prints=prints)

        # Extract X and Y coordinates of depot and all customers (first two columns) as tuples and give it as input for plot_instance
        coord = [(instance_df['X'][i], instance_df['Y'][i]) for i in range(len(instance_df))]
        
        # View clusters
        if (prints == True):
            print('\n############### CLUSTER CUSTOMERS ###############')
            plot_instance(coord=coord, sequence=None, total_costs=None, x_range=x_range, y_range=y_range, 
                    assignments=assignments, core_point_indices=core_point_indices, plot_sequence=False)

        # Define columns for displaying the instance
        instance_features = ['Instance ID', 'Number Customers', 'X', 'Y', 'Vehicle Capacity', 'Demand', 'Total Demand', 'X Depot', 'Y Depot']
        cluster_features = ['Cluster', 'Core Point', 'Outlier', 'Number Clusters', 'Number Outliers', 'Cluster Size', 'X Centroid', 'Y Centroid', 'Centroid Distance', 
                            'Centroid Distance To Depot', 'Distance To Closest Other Cluster', 'Distance To Closest Other Centroid', 'Cluster Area', 'Cluster Density', 'Cluster Demand']
        
        # Execute function for cluster features
        instance_df = fun_cluster_features(data=instance_df, assignments=assignments, core_point_indices=core_point_indices, 
                                           features=instance_features+cluster_features, prints=prints)
        
        ###############################################################################
        # Add statistics as features
        ###############################################################################

        # Extract X and Y values of the customers, excluding the first row (depot)
        x_customers = instance_df['X'].iloc[1:]
        y_customers = instance_df['Y'].iloc[1:]

        # Compute statistics for X and Y coordinates of the customers and add each of them as a column
        for statistic in [np.mean, np.std, np.max, np.min]:
            instance_df['X ' + statistic.__name__.capitalize()] = statistic(x_customers)
            instance_df['Y ' + statistic.__name__.capitalize()] = statistic(y_customers)
        
        # Calculate the correlation between X and Y of the customers as well as the skewness for X and Y and add statistics to each row as a column
        instance_df['Correlation'] = np.corrcoef(x_customers, y_customers)[0, 1] # Select first row and second column of correlation matrix
        instance_df['Skewness X'] = skew(x_customers)
        instance_df['Skewness Y'] = skew(y_customers)

        # Define columns for displaying the instance
        statistical_features = ['X Mean', 'Y Mean', 'X Std', 'Y Std', 'X Max', 'Y Max', 'X Min', 'Y Min', 'Correlation', 'Skewness X', 'Skewness Y']

        if (prints == True): print('\n############### STATISTICAL FEATURES ###############'); display(instance_df[instance_features + statistical_features])
        
        ###############################################################################
        # Solve instance and plot optimal solution
        ###############################################################################

        # Get the demands and the capacity
        demands = list(instance_df['Demand'])
        capacity = list(instance_df['Vehicle Capacity'])[0]
        
        # Use X and Y coordinates of the depot and all customers as well as demands and capacity to solve the instance and receive sequence (optimal tour) and total costs as output
        sequence, total_costs = solve_cvrp(coord, demands, capacity)

        # Plot instance with optimal tour
        if (prints == True):
            print('\n############### SOLVE INSTANCE ###############')
            plot_instance(coord=coord, sequence=sequence, total_costs=total_costs, x_range=x_range, y_range=y_range, plot_sequence=True, print_sequence=True)
        
        ###############################################################################
        # Calculate cost savings (just skip customer without solving the instance again)
        ###############################################################################
        
        # Create dictionary to store the results and iterate over each customer
        all_savings = {}
        for i in all_customers:
            # Determine origin; iterate through all trip-tuples with (origin, destination)
            for arc in sequence:
                # When a trip has customer i as destination (arc[1]), the origin of that trip an node before is arc[0]
                if (arc[1] == i): origin = arc[0]
            
            # Determine node_after; iterate through all trip-tuples with (origin, destination)
            for arc in sequence:
                # When a trip has customer i as origin (arc[0]), the destination of that trip and node after is arc[1]
                if (arc[0] == i): destination = arc[1]
            
            # Determine cost savings (saved distance by skipping customer i)
            trip_a_to_b = distance(coord[origin], coord[i])
            trip_b_to_c = distance(coord[i], coord[destination])
            trip_a_to_c = distance(coord[origin], coord[destination])
            savings = trip_a_to_b + trip_b_to_c - trip_a_to_c
            if (prints == True):
                if (i == 1): print('\n############### FEATURE COST SAVINGS ###############'); print('Sequence of optimally solved instance:', sequence)
                print('  - Customer: {}\n      Node before: {}, Node after: {}'.format(i, origin, destination))
                print('      Savings: {} + {} - {} = {}'.format(trip_a_to_b, trip_b_to_c, trip_a_to_c, savings))

            # Save in dictionary
            all_savings[i] = savings
        
        # Add savings to the DataFrame
        instance_df['Savings'] = [np.nan] + list(all_savings.values()) # Add a dummy value for the depot
        
        ###############################################################################
        # Calculate total costs for all subsets
        ###############################################################################
        
        # Iterate over all customers to create all possible subsets
        list_of_all_subsets = []
        for customer in all_customers:
            subsets = itertools.combinations(all_customers, customer) # customer 1: create object with singletons; customer 2: pairs, customer 3: trios etc.

            # Append singletons/pairs/trios... to list_of_all_subsets
            for subset in subsets:
                list_of_all_subsets.append(subset)
        
        # Solve instance for all possible subsets and store the total costs in the dictionary subset_total_costs
        subset_total_costs = {}
        for subset in list_of_all_subsets:
            
            # Use the coordinates of the depot and select the rows that contain the customers of the subset
            coordinates = [(instance_df['X'][0], instance_df['Y'][0])] + [(instance_df['X'][i], instance_df['Y'][i]) for i in subset]
            
            # Use these coordinates as input for the function solve_cvrp to get the optimal tour for the subset and store the result in the dictionary
            demands = [0] + [instance_df['Demand'][i] for i in subset]
            sequence, total_costs = solve_cvrp(coordinates, demands, capacity)
            subset_total_costs[subset] = total_costs
        
        if (prints == True):
            print('\n############### TOTAL COSTS OF ALL SUBSETS ###############')
            print('Every third element of subset_total_costs:'); display([{key: subset_total_costs[key]} for key in list(subset_total_costs.keys())[::3]])
        
        ###############################################################################
        # Calculate marginal costs (solve instance without customer)
        ###############################################################################

        # Initialize an empty list to store the marginal costs
        all_marginal_costs = []

        # Iterate over all customers to get the costs of the subset without the customer and compute the marginal costs
        for i in all_customers:
            set_without_customer = set(all_customers) - set([i])
            costs_without_customer = subset_total_costs[tuple(set_without_customer)]
            marginal_costs = total_costs - costs_without_customer

            if (prints == True):
                if (i == 1): print('\n############### FEATURE MARGINAL COSTS ###############')
                print('  - Customer {}\n      Set without customer: {}\n      Costs without customer: {}'.format(i, set_without_customer, costs_without_customer))
                print('      Marginal costs: {} - {} = {}'.format(total_costs, costs_without_customer, marginal_costs))

            # Append the marginal cost to the list
            all_marginal_costs.append(marginal_costs)
        
        # Add the marginal costs to the DataFrame and also a column for total costs
        instance_df['Marginal Costs'] = [np.nan] + all_marginal_costs # Add a dummy value for the depot
        instance_df['Total Costs'] = total_costs

        ###############################################################################
        # Calculate Shapley value
        ###############################################################################

        # Calculate Shapley value for each customer
        shapley_values = [0] # Zero for depot
        for i in all_customers:
            shapley_value = fun_shapley_value(player_index=i, characteristic_function=subset_total_costs, prints=prints)
            shapley_values.append(shapley_value)
        
        # Define columns for displaying the instance
        cost_features = ['Savings', 'Total Costs', 'Marginal Costs', 'Shapley Value']

        # Add Shapley values to the DataFrame
        instance_df['Shapley Value'] = shapley_values
        if (prints == True): display(instance_df[instance_features + cost_features])

        ###############################################################################
        # Add ratio features
        ###############################################################################

        # Define features for which the ratio should be computed
        ratio_features = ['Demand', 'Depot Distance', 'Closest Customer Distance (CCD)', '2nd CCD', '3rd CCD', '4th CCD', 'Mean Distance To Other Customers', 
                          'Gravity Center Distance', 'Centroid Distance', 'Centroid Distance To Depot', 'Distance To Closest Other Cluster', 
                          'Distance To Closest Other Centroid', 'Cluster Area', 'Cluster Density', 'Cluster Demand', 'Savings', 'Marginal Costs']

        # Compute mean of all ratio_features (without the depot) and divide their values by mean to obtain ratio column which is inserted before the Shapley value
        for feature in ratio_features:
            mean = np.mean(instance_df.loc[1:, feature])
            ratio = instance_df.loc[1:, feature] / mean
            instance_df.insert(loc=len(instance_df.columns) - 1, column=feature + str(' Ratio'), value=ratio)


        if (prints == True):
            print('\n############### RATIO FEATURES ###############')
            print('No ratio features:\n', np.sort(list(set(instance_df.columns) - set(ratio_features) - set([i + str(' Ratio') for i in ratio_features]))))
            display(instance_df[instance_features + [i + str(' Ratio') for i in ratio_features]])
        
        ###############################################################################
        # Add CVRP specific features
        ###############################################################################        
        # Add the proportion of each customers demand within its cluster
        instance_df['Customer Cluster Demand Ratio'] =  instance_df['Demand'] / (instance_df['Cluster Demand'] / instance_df['Cluster Size'])

        
        # Drop depot row and reset index
        instance_df.drop(index=0, inplace=True)
        instance_df.reset_index(drop=True)

        # Merge instances
        df_final = pd.concat([df_final, instance_df], ignore_index=True)
    
    # Stop time count for instance size and make print to show progress during generation
    run_time[num_customers] = time.time() - start
    if (num_customers_list[-1] > 10): print('- Instance size {} completed! Run time: {}'.format(num_customers, 
                                                                                                       fun_convert_time(seconds=run_time[num_customers])))

    # View final instance when there was only one generated per instance size
    if (number_of_instances_per_size == 1):
        print('\n############### FINAL INSTANCE ###############'); display(instance_df)
        plot_instance(coord=coord, sequence=sequence, total_costs=total_costs, x_range=x_range, y_range=y_range, 
                      assignments=assignments, core_point_indices=core_point_indices, plot_sequence=True, print_sequence=False)

    # Else view run times and final DataFrame with merged instances
    elif (instance_id == (100000 * num_customers_list[-1] * start_value) + number_of_instances_per_size):
        print('-> Total run time: ', fun_convert_time(seconds=sum(run_time.values())))
        display({'Instance size: {} run time'.format(key): fun_convert_time(seconds=value) for key, value in run_time.items()})
        display(df_final)

# Save file
fun_save_file(data=df_final, subfolder_path='..\\..\\01_data\\02_CVRP', name='cvrp_instances_d.xlsx')
# Out:
# ############### INSTANCE ###############
#    Instance ID  Number Customers          X          Y  Vehicle Capacity  \
# 0       600000                 6  50.972432  22.758978              11.0
# 1       600000                 6  94.706549  47.866763              11.0
# 2       600000                 6  37.282589  64.302568              11.0
# 3       600000                 6  88.004425  92.854727              11.0
# 4       600000                 6  11.079519  36.262980              11.0
# 5       600000                 6  56.817199  28.510302              11.0
# 6       600000                 6  90.206480  47.921843              11.0
#
#    Demand  Total Demand    X Depot    Y Depot
# 0     0.0          12.0  50.972432  22.758978
# 1     1.0          12.0  50.972432  22.758978
# 2     5.0          12.0  50.972432  22.758978
# 3     1.0          12.0  50.972432  22.758978
# 4     1.0          12.0  50.972432  22.758978
# 5     3.0          12.0  50.972432  22.758978
# 6     1.0          12.0  50.972432  22.758978
# ############### DISTANCE FEATURES ###############
# Customer distances:
#            1          2          3          4          5          6
# 1        NaN  59.729782  45.484452  84.428242  42.547332   4.500407
# 2  59.729782        NaN  58.205930  38.377330  40.776063  55.400960
# 3  45.484452  58.205930        NaN  95.499042  71.504182  44.986810
# 4  84.428242  38.377330  95.499042        NaN  46.390079  79.981280
# 5  42.547332  40.776063  71.504182  46.390079        NaN  38.621911
# 6   4.500407  55.400960  44.986810  79.981280  38.621911        NaN
#    Instance ID  Number Customers          X          Y  Vehicle Capacity  \
# 0       600000                 6  50.972432  22.758978              11.0
# 1       600000                 6  94.706549  47.866763              11.0
# 2       600000                 6  37.282589  64.302568              11.0
# 3       600000                 6  88.004425  92.854727              11.0
# 4       600000                 6  11.079519  36.262980              11.0
# 5       600000                 6  56.817199  28.510302              11.0
# 6       600000                 6  90.206480  47.921843              11.0
#
#    Demand  Total Demand    X Depot    Y Depot  Depot Distance  ...    3rd CCD  \
# 0     0.0          12.0  50.972432  22.758978        0.000000  ...        NaN
# 1     1.0          12.0  50.972432  22.758978       50.428899  ...  45.484452
# 2     5.0          12.0  50.972432  22.758978       43.741075  ...  55.400960
# 3     1.0          12.0  50.972432  22.758978       79.276620  ...  58.205930
# 4     1.0          12.0  50.972432  22.758978       42.116536  ...  79.981280
# 5     3.0          12.0  50.972432  22.758978        8.199941  ...  42.547332
# 6     1.0          12.0  50.972432  22.758978       46.609873  ...  44.986810
#
#      4th CCD    5th CCD   6th CCD   7th CCD   8th CCD   9th CCD  10th CCD  \
# 0        NaN        NaN       NaN       NaN       NaN       NaN       NaN
# 1  59.729782  84.428242  100000.0  100000.0  100000.0  100000.0  100000.0
# 2  58.205930  59.729782  100000.0  100000.0  100000.0  100000.0  100000.0
# 3  71.504182  95.499042  100000.0  100000.0  100000.0  100000.0  100000.0
# 4  84.428242  95.499042  100000.0  100000.0  100000.0  100000.0  100000.0
# 5  46.390079  71.504182  100000.0  100000.0  100000.0  100000.0  100000.0
# 6  55.400960  79.981280  100000.0  100000.0  100000.0  100000.0  100000.0
#
#    Mean Distance To Other Customers  Gravity Center Distance
# 0                               NaN                      NaN
# 1                         47.338043                32.096023
# 2                         50.498013                28.125134
# 3                         63.136083                47.080220
# 4                         68.935195                54.552494
# 5                         47.967914                25.216698
# 6                         44.698273                27.651940
#
# [7 rows x 22 columns]
# ############### CLUSTER FEATURES ###############
# - Min cluster size: 3 with 33 eps
#   labels: [-1 -1 -1 -1 -1 -1]
#   Core points: []
# - Min cluster size: 2 with 40 eps
#   labels: [ 0  1 -1  1  0  0]
#   Core points: [1 2 4 5 6]
# - Min cluster size: 2 with 55 eps
#   labels: [ 0  1 -1  1  0  0]
#   Core points: []
#
# ############### CLUSTER CUSTOMERS ###############
#   - Cluster: 0
#       Centroid: {'X': 80.57674288720175, 'Y': 41.43296939852687}
#       Distances to centroid: {'Customer 1': 15.525628414484064, 'Customer 5': 27.046464594887727, 'Customer 6': 11.61194715377053}
#   - Cluster: 1
#       Centroid: {'X': 24.18105388841962, 'Y': 50.28277392176717}
#       Distances to centroid: {'Customer 2': 19.188664910555026, 'Customer 4': 19.18866491055503}
#    Instance ID  Number Customers          X          Y  Vehicle Capacity  \
# 0       600000                 6  50.972432  22.758978              11.0
# 1       600000                 6  94.706549  47.866763              11.0
# 2       600000                 6  37.282589  64.302568              11.0
# 3       600000                 6  88.004425  92.854727              11.0
# 4       600000                 6  11.079519  36.262980              11.0
# 5       600000                 6  56.817199  28.510302              11.0
# 6       600000                 6  90.206480  47.921843              11.0
#
#    Demand  Total Demand    X Depot    Y Depot  Cluster  ...  Cluster Size  \
# 0     0.0          12.0  50.972432  22.758978       -1  ...            -1
# 1     1.0          12.0  50.972432  22.758978        0  ...             3
# 2     5.0          12.0  50.972432  22.758978        1  ...             2
# 3     1.0          12.0  50.972432  22.758978       -1  ...             1
# 4     1.0          12.0  50.972432  22.758978        1  ...             2
# 5     3.0          12.0  50.972432  22.758978        0  ...             3
# 6     1.0          12.0  50.972432  22.758978        0  ...             3
#
#    X Centroid  Y Centroid  Centroid Distance  Centroid Distance To Depot  \
# 0   -1.000000   -1.000000          -1.000000                   -1.000000
# 1   80.576743   41.432969          15.525628                   35.001902
# 2   24.181054   50.282774          19.188665                   38.410119
# 3   88.004425   92.854727           0.000000                   79.276620
# 4   24.181054   50.282774          19.188665                   38.410119
# 5   80.576743   41.432969          27.046465                   35.001902
# 6   80.576743   41.432969          11.611947                   35.001902
#
#    Distance To Closest Other Cluster  Distance To Closest Other Centroid  \
# 0                          -1.000000                           -1.000000
# 1                          59.729782                           70.566866
# 2                          40.776063                           48.963275
# 3                          44.986810                           51.955439
# 4                          46.390079                           69.689260
# 5                          40.776063                           39.232111
# 6                          55.400960                           66.067623
#
#    Cluster Area  Cluster Density  Cluster Demand
# 0     -1.000000        -1.000000            -1.0
# 1   1127.519840         0.002661             5.0
# 2    617.494588         0.003239             6.0
# 3      1.000000         1.000000             1.0
# 4    617.494588         0.003239             6.0
# 5   1127.519840         0.002661             5.0
# 6   1127.519840         0.002661             5.0
#
# [7 rows x 24 columns]
# ############### STATISTICAL FEATURES ###############
#    Instance ID  Number Customers          X          Y  Vehicle Capacity  \
# 0       600000                 6  50.972432  22.758978              11.0
# 1       600000                 6  94.706549  47.866763              11.0
# 2       600000                 6  37.282589  64.302568              11.0
# 3       600000                 6  88.004425  92.854727              11.0
# 4       600000                 6  11.079519  36.262980              11.0
# 5       600000                 6  56.817199  28.510302              11.0
# 6       600000                 6  90.206480  47.921843              11.0
#
#    Demand  Total Demand    X Depot    Y Depot     X Mean     Y Mean  \
# 0     0.0          12.0  50.972432  22.758978  63.016127  52.953197
# 1     1.0          12.0  50.972432  22.758978  63.016127  52.953197
# 2     5.0          12.0  50.972432  22.758978  63.016127  52.953197
# 3     1.0          12.0  50.972432  22.758978  63.016127  52.953197
# 4     1.0          12.0  50.972432  22.758978  63.016127  52.953197
# 5     3.0          12.0  50.972432  22.758978  63.016127  52.953197
# 6     1.0          12.0  50.972432  22.758978  63.016127  52.953197
#
#        X Std      Y Std      X Max      Y Max      X Min      Y Min  \
# 0  31.000178  21.008511  94.706549  92.854727  11.079519  28.510302
# 1  31.000178  21.008511  94.706549  92.854727  11.079519  28.510302
# 2  31.000178  21.008511  94.706549  92.854727  11.079519  28.510302
# 3  31.000178  21.008511  94.706549  92.854727  11.079519  28.510302
# 4  31.000178  21.008511  94.706549  92.854727  11.079519  28.510302
# 5  31.000178  21.008511  94.706549  92.854727  11.079519  28.510302
# 6  31.000178  21.008511  94.706549  92.854727  11.079519  28.510302
#
#    Correlation  Skewness X  Skewness Y
# 0     0.364768   -0.502617    0.817467
# 1     0.364768   -0.502617    0.817467
# 2     0.364768   -0.502617    0.817467
# 3     0.364768   -0.502617    0.817467
# 4     0.364768   -0.502617    0.817467
# 5     0.364768   -0.502617    0.817467
# 6     0.364768   -0.502617    0.817467
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-04
#
# ############### SOLVE INSTANCE ###############
# Total costs: 251.69440915430616
# Optimal solution: [(0, 5), (5, 0), (0, 6), (6, 1), (1, 3), (3, 2), (2, 4), (4, 0)]
# ############### FEATURE COST SAVINGS ###############
# Sequence of optimally solved instance: [(0, 5), (5, 0), (0, 6), (6, 1), (1, 3), (3, 2), (2, 4), (4, 0)]
#   - Customer: 1
#       Node before: 6, Node after: 3
#       Savings: 4.500406831684757 + 45.4844517084111 - 44.986809900192384 = 4.998048639903473
#   - Customer: 2
#       Node before: 3, Node after: 4
#       Savings: 58.20593040282776 + 38.37732982111006 - 95.49904195606739 = 1.0842182678704404
#   - Customer: 3
#       Node before: 1, Node after: 2
#       Savings: 45.4844517084111 + 58.20593040282776 - 59.72978230563171 = 43.96059980560715
#   - Customer: 4
#       Node before: 2, Node after: 0
#       Savings: 38.37732982111006 + 42.11653586376058 - 43.74107512892634 = 36.7527905559443
#   - Customer: 5
#       Node before: 0, Node after: 0
#       Savings: 8.199940656348167 + 8.199940656348167 - 0.0 = 16.399881312696333
#   - Customer: 6
#       Node before: 0, Node after: 1
#       Savings: 46.60987321381558 + 4.500406831684757 - 50.42889944951885 = 0.6813805959814871
#
# ############### TOTAL COSTS OF ALL SUBSETS ###############
# Every third element of subset_total_costs:
# [{(1,): 100.8577988990377},
#  {(4,): 84.23307172752116},
#  {(1, 2): 153.8997568840769},
#  {(1, 5): 101.17617201742571},
#  {(2, 4): 124.23494081379698},
#  {(3, 4): 216.89219751856717},
#  {(4, 5): 96.70655597855811},
#  {(1, 2, 3): 197.86035668968404},
#  {(1, 2, 6): 154.07134106120088},
#  {(1, 3, 6): 175.87135145265063},
#  {(1, 5, 6): 101.75115768655945},
#  {(2, 3, 6): 193.54368864576207},
#  {(2, 5, 6): 145.96388618535312},
#  {(3, 5, 6): 171.0852810042874},
#  {(1, 2, 3, 5): 198.17872980807203},
#  {(1, 2, 4, 6): 190.82413161714518},
#  {(1, 3, 4, 6): 234.21030957373944},
#  {(2, 3, 4, 5): 218.40391886851745},
#  {(2, 4, 5, 6): 182.71667674129742},
#  {(1, 2, 3, 4, 6): 235.29452784160986},
#  {(1, 3, 4, 5, 6): 234.4222877652797}]
# ############### FEATURE MARGINAL COSTS ###############
#   - Customer 1
#       Set without customer: {2, 3, 4, 5, 6}
#       Costs without customer: 230.5084573932466
#       Marginal costs: 251.69440915430616 - 230.5084573932466 = 21.185951761059556
#   - Customer 2
#       Set without customer: {1, 3, 4, 5, 6}
#       Costs without customer: 234.4222877652797
#       Marginal costs: 251.69440915430616 - 234.4222877652797 = 17.272121389026466
#   - Customer 3
#       Set without customer: {1, 2, 4, 5, 6}
#       Costs without customer: 191.14250473553318
#       Marginal costs: 251.69440915430616 - 191.14250473553318 = 60.55190441877298
#   - Customer 4
#       Set without customer: {1, 2, 3, 5, 6}
#       Costs without customer: 198.7537154772058
#       Marginal costs: 251.69440915430616 - 198.7537154772058 = 52.94069367710037
#   - Customer 5
#       Set without customer: {1, 2, 3, 4, 6}
#       Costs without customer: 235.29452784160986
#       Marginal costs: 251.69440915430616 - 235.29452784160986 = 16.399881312696294
#   - Customer 6
#       Set without customer: {1, 2, 3, 4, 5}
#       Costs without customer: 234.93152036401636
#       Marginal costs: 251.69440915430616 - 234.93152036401636 = 16.762888790289793
#
# ############### SHAPLEY VALUE ###############
#   - Customer: 1
#       Subset: (1,), Total costs: 100.8577988990377
#         Subset without customer: set(), Total costs: 0
#         Marginal contribution: 100.8577988990377 - 0 = 100.8577988990377
#       Subset: (1, 2), Total costs: 153.8997568840769
#         Subset without customer: {2}, Total costs: 87.48215025785268
#         Marginal contribution: 153.8997568840769 - 87.48215025785268 = 66.41760662622423
#       Subset: (1, 3), Total costs: 175.1899708566691
#         Subset without customer: {3}, Total costs: 158.55323939747836
#         Marginal contribution: 175.1899708566691 - 158.55323939747836 = 16.63673145919074
#       Subset: (1, 4), Total costs: 176.97367764432218
#         Subset without customer: {4}, Total costs: 84.23307172752116
#         Marginal contribution: 176.97367764432218 - 84.23307172752116 = 92.74060591680102
#       Subset: (1, 5), Total costs: 101.17617201742571
#         Subset without customer: {5}, Total costs: 16.399881312696333
#         Marginal contribution: 101.17617201742571 - 16.399881312696333 = 84.77629070472938
#       Subset: (1, 6), Total costs: 101.5391794950192
#         Subset without customer: {6}, Total costs: 93.21974642763116
#         Marginal contribution: 101.5391794950192 - 93.21974642763116 = 8.319433067388033
#       Subset: (1, 2, 3), Total costs: 197.86035668968404
#         Subset without customer: {2, 3}, Total costs: 181.22362523049327
#         Marginal contribution: 197.86035668968404 - 181.22362523049327 = 16.63673145919077
#       Subset: (1, 2, 4), Total costs: 190.6525474400212
#         Subset without customer: {2, 4}, Total costs: 124.23494081379698
#         Marginal contribution: 190.6525474400212 - 124.23494081379698 = 66.41760662622423
#       Subset: (1, 2, 5), Total costs: 154.2181300024649
#         Subset without customer: {2, 5}, Total costs: 92.7170791297204
#         Marginal contribution: 154.2181300024649 - 92.7170791297204 = 61.5010508727445
#       Subset: (1, 2, 6), Total costs: 154.07134106120088
#         Subset without customer: {2, 6}, Total costs: 145.7519079938129
#         Marginal contribution: 154.07134106120088 - 145.7519079938129 = 8.31943306738799
#       Subset: (1, 3, 4), Total costs: 233.52892897775791
#         Subset without customer: {3, 4}, Total costs: 216.89219751856717
#         Marginal contribution: 233.52892897775791 - 216.89219751856717 = 16.63673145919074
#       Subset: (1, 3, 5), Total costs: 175.50834397505716
#         Subset without customer: {3, 5}, Total costs: 158.98074247955822
#         Marginal contribution: 175.50834397505716 - 158.98074247955822 = 16.527601495498942
#       Subset: (1, 3, 6), Total costs: 175.87135145265063
#         Subset without customer: {3, 6}, Total costs: 170.87330281274714
#         Marginal contribution: 175.87135145265063 - 170.87330281274714 = 4.998048639903487
#       Subset: (1, 4, 5), Total costs: 177.2920507627102
#         Subset without customer: {4, 5}, Total costs: 96.70655597855811
#         Marginal contribution: 177.2920507627102 - 96.70655597855811 = 80.58549478415209
#       Subset: (1, 4, 6), Total costs: 177.02712179213282
#         Subset without customer: {4, 6}, Total costs: 168.7076887247448
#         Marginal contribution: 177.02712179213282 - 168.7076887247448 = 8.319433067388019
#       Subset: (1, 5, 6), Total costs: 101.75115768655945
#         Subset without customer: {5, 6}, Total costs: 93.43172461917142
#         Marginal contribution: 101.75115768655945 - 93.43172461917142 = 8.319433067388033
#       Subset: (1, 2, 3, 4), Total costs: 234.61314724562834
#         Subset without customer: {2, 3, 4}, Total costs: 217.9764157864376
#         Marginal contribution: 234.61314724562834 - 217.9764157864376 = 16.63673145919074
#       Subset: (1, 2, 3, 5), Total costs: 198.17872980807203
#         Subset without customer: {2, 3, 5}, Total costs: 181.65112831257312
#         Marginal contribution: 198.17872980807203 - 181.65112831257312 = 16.527601495498914
#       Subset: (1, 2, 3, 6), Total costs: 198.54173728566553
#         Subset without customer: {2, 3, 6}, Total costs: 193.54368864576207
#         Marginal contribution: 198.54173728566553 - 193.54368864576207 = 4.998048639903459
#       Subset: (1, 2, 4, 5), Total costs: 190.9709205584092
#         Subset without customer: {2, 4, 5}, Total costs: 129.4698696856647
#         Marginal contribution: 190.9709205584092 - 129.4698696856647 = 61.501050872744514
#       Subset: (1, 2, 4, 6), Total costs: 190.82413161714518
#         Subset without customer: {2, 4, 6}, Total costs: 182.50469854975717
#         Marginal contribution: 190.82413161714518 - 182.50469854975717 = 8.319433067388019
#       Subset: (1, 2, 5, 6), Total costs: 154.3897141795889
#         Subset without customer: {2, 5, 6}, Total costs: 145.96388618535312
#         Marginal contribution: 154.3897141795889 - 145.96388618535312 = 8.425827994235789
#       Subset: (1, 3, 4, 5), Total costs: 233.84730209614594
#         Subset without customer: {3, 4, 5}, Total costs: 217.319700600647
#         Marginal contribution: 233.84730209614594 - 217.319700600647 = 16.527601495498942
#       Subset: (1, 3, 4, 6), Total costs: 234.21030957373944
#         Subset without customer: {3, 4, 6}, Total costs: 229.21226093383595
#         Marginal contribution: 234.21030957373944 - 229.21226093383595 = 4.998048639903487
#       Subset: (1, 3, 5, 6), Total costs: 176.08332964419088
#         Subset without customer: {3, 5, 6}, Total costs: 171.0852810042874
#         Marginal contribution: 176.08332964419088 - 171.0852810042874 = 4.998048639903487
#       Subset: (1, 4, 5, 6), Total costs: 177.34549491052084
#         Subset without customer: {4, 5, 6}, Total costs: 168.91966691628505
#         Marginal contribution: 177.34549491052084 - 168.91966691628505 = 8.425827994235789
#       Subset: (1, 2, 3, 4, 5), Total costs: 234.93152036401636
#         Subset without customer: {2, 3, 4, 5}, Total costs: 218.40391886851745
#         Marginal contribution: 234.93152036401636 - 218.40391886851745 = 16.527601495498914
#       Subset: (1, 2, 3, 4, 6), Total costs: 235.29452784160986
#         Subset without customer: {2, 3, 4, 6}, Total costs: 230.29647920170638
#         Marginal contribution: 235.29452784160986 - 230.29647920170638 = 4.998048639903487
#       Subset: (1, 2, 3, 5, 6), Total costs: 198.7537154772058
#         Subset without customer: {2, 3, 5, 6}, Total costs: 193.75566683730233
#         Marginal contribution: 198.7537154772058 - 193.75566683730233 = 4.998048639903459
#       Subset: (1, 2, 4, 5, 6), Total costs: 191.14250473553318
#         Subset without customer: {2, 4, 5, 6}, Total costs: 182.71667674129742
#         Marginal contribution: 191.14250473553318 - 182.71667674129742 = 8.42582799423576
#       Subset: (1, 3, 4, 5, 6), Total costs: 234.4222877652797
#         Subset without customer: {3, 4, 5, 6}, Total costs: 229.42423912537618
#         Marginal contribution: 234.4222877652797 - 229.42423912537618 = 4.998048639903516
#       Subset: (1, 2, 3, 4, 5, 6), Total costs: 251.69440915430616
#         Subset without customer: {2, 3, 4, 5, 6}, Total costs: 230.5084573932466
#         Marginal contribution: 251.69440915430616 - 230.5084573932466 = 21.185951761059556
#    Shapley value: 37.962229630101696
#
#   - Customer: 2
#       Subset: (2,), Total costs: 87.48215025785268
#         Subset without customer: set(), Total costs: 0
#         Marginal contribution: 87.48215025785268 - 0 = 87.48215025785268
#       Subset: (1, 2), Total costs: 153.8997568840769
#         Subset without customer: {1}, Total costs: 100.8577988990377
#         Marginal contribution: 153.8997568840769 - 100.8577988990377 = 53.041957985039204
#       Subset: (2, 3), Total costs: 181.22362523049327
#         Subset without customer: {3}, Total costs: 158.55323939747836
#         Marginal contribution: 181.22362523049327 - 158.55323939747836 = 22.670385833014905
#       Subset: (2, 4), Total costs: 124.23494081379698
#         Subset without customer: {4}, Total costs: 84.23307172752116
#         Marginal contribution: 124.23494081379698 - 84.23307172752116 = 40.00186908627582
#       Subset: (2, 5), Total costs: 92.7170791297204
#         Subset without customer: {5}, Total costs: 16.399881312696333
#         Marginal contribution: 92.7170791297204 - 16.399881312696333 = 76.31719781702407
#       Subset: (2, 6), Total costs: 145.7519079938129
#         Subset without customer: {6}, Total costs: 93.21974642763116
#         Marginal contribution: 145.7519079938129 - 93.21974642763116 = 52.53216156618173
#       Subset: (1, 2, 3), Total costs: 197.86035668968404
#         Subset without customer: {1, 3}, Total costs: 175.1899708566691
#         Marginal contribution: 197.86035668968404 - 175.1899708566691 = 22.670385833014933
#       Subset: (1, 2, 4), Total costs: 190.6525474400212
#         Subset without customer: {1, 4}, Total costs: 176.97367764432218
#         Marginal contribution: 190.6525474400212 - 176.97367764432218 = 13.678869795699029
#       Subset: (1, 2, 5), Total costs: 154.2181300024649
#         Subset without customer: {1, 5}, Total costs: 101.17617201742571
#         Marginal contribution: 154.2181300024649 - 101.17617201742571 = 53.04195798503919
#       Subset: (1, 2, 6), Total costs: 154.07134106120088
#         Subset without customer: {1, 6}, Total costs: 101.5391794950192
#         Marginal contribution: 154.07134106120088 - 101.5391794950192 = 52.532161566181685
#       Subset: (2, 3, 4), Total costs: 217.9764157864376
#         Subset without customer: {3, 4}, Total costs: 216.89219751856717
#         Marginal contribution: 217.9764157864376 - 216.89219751856717 = 1.0842182678704262
#       Subset: (2, 3, 5), Total costs: 181.65112831257312
#         Subset without customer: {3, 5}, Total costs: 158.98074247955822
#         Marginal contribution: 181.65112831257312 - 158.98074247955822 = 22.670385833014905
#       Subset: (2, 3, 6), Total costs: 193.54368864576207
#         Subset without customer: {3, 6}, Total costs: 170.87330281274714
#         Marginal contribution: 193.54368864576207 - 170.87330281274714 = 22.670385833014933
#       Subset: (2, 4, 5), Total costs: 129.4698696856647
#         Subset without customer: {4, 5}, Total costs: 96.70655597855811
#         Marginal contribution: 129.4698696856647 - 96.70655597855811 = 32.763313707106576
#       Subset: (2, 4, 6), Total costs: 182.50469854975717
#         Subset without customer: {4, 6}, Total costs: 168.7076887247448
#         Marginal contribution: 182.50469854975717 - 168.7076887247448 = 13.797009825012367
#       Subset: (2, 5, 6), Total costs: 145.96388618535312
#         Subset without customer: {5, 6}, Total costs: 93.43172461917142
#         Marginal contribution: 145.96388618535312 - 93.43172461917142 = 52.5321615661817
#       Subset: (1, 2, 3, 4), Total costs: 234.61314724562834
#         Subset without customer: {1, 3, 4}, Total costs: 233.52892897775791
#         Marginal contribution: 234.61314724562834 - 233.52892897775791 = 1.0842182678704262
#       Subset: (1, 2, 3, 5), Total costs: 198.17872980807203
#         Subset without customer: {1, 3, 5}, Total costs: 175.50834397505716
#         Marginal contribution: 198.17872980807203 - 175.50834397505716 = 22.670385833014876
#       Subset: (1, 2, 3, 6), Total costs: 198.54173728566553
#         Subset without customer: {1, 3, 6}, Total costs: 175.87135145265063
#         Marginal contribution: 198.54173728566553 - 175.87135145265063 = 22.670385833014905
#       Subset: (1, 2, 4, 5), Total costs: 190.9709205584092
#         Subset without customer: {1, 4, 5}, Total costs: 177.2920507627102
#         Marginal contribution: 190.9709205584092 - 177.2920507627102 = 13.678869795699
#       Subset: (1, 2, 4, 6), Total costs: 190.82413161714518
#         Subset without customer: {1, 4, 6}, Total costs: 177.02712179213282
#         Marginal contribution: 190.82413161714518 - 177.02712179213282 = 13.797009825012367
#       Subset: (1, 2, 5, 6), Total costs: 154.3897141795889
#         Subset without customer: {1, 5, 6}, Total costs: 101.75115768655945
#         Marginal contribution: 154.3897141795889 - 101.75115768655945 = 52.638556493029455
#       Subset: (2, 3, 4, 5), Total costs: 218.40391886851745
#         Subset without customer: {3, 4, 5}, Total costs: 217.319700600647
#         Marginal contribution: 218.40391886851745 - 217.319700600647 = 1.0842182678704546
#       Subset: (2, 3, 4, 6), Total costs: 230.29647920170638
#         Subset without customer: {3, 4, 6}, Total costs: 229.21226093383595
#         Marginal contribution: 230.29647920170638 - 229.21226093383595 = 1.0842182678704262
#       Subset: (2, 3, 5, 6), Total costs: 193.75566683730233
#         Subset without customer: {3, 5, 6}, Total costs: 171.0852810042874
#         Marginal contribution: 193.75566683730233 - 171.0852810042874 = 22.670385833014933
#       Subset: (2, 4, 5, 6), Total costs: 182.71667674129742
#         Subset without customer: {4, 5, 6}, Total costs: 168.91966691628505
#         Marginal contribution: 182.71667674129742 - 168.91966691628505 = 13.797009825012367
#       Subset: (1, 2, 3, 4, 5), Total costs: 234.93152036401636
#         Subset without customer: {1, 3, 4, 5}, Total costs: 233.84730209614594
#         Marginal contribution: 234.93152036401636 - 233.84730209614594 = 1.0842182678704262
#       Subset: (1, 2, 3, 4, 6), Total costs: 235.29452784160986
#         Subset without customer: {1, 3, 4, 6}, Total costs: 234.21030957373944
#         Marginal contribution: 235.29452784160986 - 234.21030957373944 = 1.0842182678704262
#       Subset: (1, 2, 3, 5, 6), Total costs: 198.7537154772058
#         Subset without customer: {1, 3, 5, 6}, Total costs: 176.08332964419088
#         Marginal contribution: 198.7537154772058 - 176.08332964419088 = 22.670385833014905
#       Subset: (1, 2, 4, 5, 6), Total costs: 191.14250473553318
#         Subset without customer: {1, 4, 5, 6}, Total costs: 177.34549491052084
#         Marginal contribution: 191.14250473553318 - 177.34549491052084 = 13.797009825012339
#       Subset: (2, 3, 4, 5, 6), Total costs: 230.5084573932466
#         Subset without customer: {3, 4, 5, 6}, Total costs: 229.42423912537618
#         Marginal contribution: 230.5084573932466 - 229.42423912537618 = 1.0842182678704262
#       Subset: (1, 2, 3, 4, 5, 6), Total costs: 251.69440915430616
#         Subset without customer: {1, 3, 4, 5, 6}, Total costs: 234.4222877652797
#         Marginal contribution: 251.69440915430616 - 234.4222877652797 = 17.272121389026466
#    Shapley value: 34.47876784034475
#
#   - Customer: 3
#       Subset: (3,), Total costs: 158.55323939747836
#         Subset without customer: set(), Total costs: 0
#         Marginal contribution: 158.55323939747836 - 0 = 158.55323939747836
#       Subset: (1, 3), Total costs: 175.1899708566691
#         Subset without customer: {1}, Total costs: 100.8577988990377
#         Marginal contribution: 175.1899708566691 - 100.8577988990377 = 74.3321719576314
#       Subset: (2, 3), Total costs: 181.22362523049327
#         Subset without customer: {2}, Total costs: 87.48215025785268
#         Marginal contribution: 181.22362523049327 - 87.48215025785268 = 93.74147497264059
#       Subset: (3, 4), Total costs: 216.89219751856717
#         Subset without customer: {4}, Total costs: 84.23307172752116
#         Marginal contribution: 216.89219751856717 - 84.23307172752116 = 132.659125791046
#       Subset: (3, 5), Total costs: 158.98074247955822
#         Subset without customer: {5}, Total costs: 16.399881312696333
#         Marginal contribution: 158.98074247955822 - 16.399881312696333 = 142.5808611668619
#       Subset: (3, 6), Total costs: 170.87330281274714
#         Subset without customer: {6}, Total costs: 93.21974642763116
#         Marginal contribution: 170.87330281274714 - 93.21974642763116 = 77.65355638511598
#       Subset: (1, 2, 3), Total costs: 197.86035668968404
#         Subset without customer: {1, 2}, Total costs: 153.8997568840769
#         Marginal contribution: 197.86035668968404 - 153.8997568840769 = 43.96059980560713
#       Subset: (1, 3, 4), Total costs: 233.52892897775791
#         Subset without customer: {1, 4}, Total costs: 176.97367764432218
#         Marginal contribution: 233.52892897775791 - 176.97367764432218 = 56.555251333435734
#       Subset: (1, 3, 5), Total costs: 175.50834397505716
#         Subset without customer: {1, 5}, Total costs: 101.17617201742571
#         Marginal contribution: 175.50834397505716 - 101.17617201742571 = 74.33217195763145
#       Subset: (1, 3, 6), Total costs: 175.87135145265063
#         Subset without customer: {1, 6}, Total costs: 101.5391794950192
#         Marginal contribution: 175.87135145265063 - 101.5391794950192 = 74.33217195763143
#       Subset: (2, 3, 4), Total costs: 217.9764157864376
#         Subset without customer: {2, 4}, Total costs: 124.23494081379698
#         Marginal contribution: 217.9764157864376 - 124.23494081379698 = 93.74147497264062
#       Subset: (2, 3, 5), Total costs: 181.65112831257312
#         Subset without customer: {2, 5}, Total costs: 92.7170791297204
#         Marginal contribution: 181.65112831257312 - 92.7170791297204 = 88.93404918285272
#       Subset: (2, 3, 6), Total costs: 193.54368864576207
#         Subset without customer: {2, 6}, Total costs: 145.7519079938129
#         Marginal contribution: 193.54368864576207 - 145.7519079938129 = 47.79178065194918
#       Subset: (3, 4, 5), Total costs: 217.319700600647
#         Subset without customer: {4, 5}, Total costs: 96.70655597855811
#         Marginal contribution: 217.319700600647 - 96.70655597855811 = 120.61314462208888
#       Subset: (3, 4, 6), Total costs: 229.21226093383595
#         Subset without customer: {4, 6}, Total costs: 168.7076887247448
#         Marginal contribution: 229.21226093383595 - 168.7076887247448 = 60.50457220909115
#       Subset: (3, 5, 6), Total costs: 171.0852810042874
#         Subset without customer: {5, 6}, Total costs: 93.43172461917142
#         Marginal contribution: 171.0852810042874 - 93.43172461917142 = 77.65355638511598
#       Subset: (1, 2, 3, 4), Total costs: 234.61314724562834
#         Subset without customer: {1, 2, 4}, Total costs: 190.6525474400212
#         Marginal contribution: 234.61314724562834 - 190.6525474400212 = 43.96059980560713
#       Subset: (1, 2, 3, 5), Total costs: 198.17872980807203
#         Subset without customer: {1, 2, 5}, Total costs: 154.2181300024649
#         Marginal contribution: 198.17872980807203 - 154.2181300024649 = 43.96059980560713
#       Subset: (1, 2, 3, 6), Total costs: 198.54173728566553
#         Subset without customer: {1, 2, 6}, Total costs: 154.07134106120088
#         Marginal contribution: 198.54173728566553 - 154.07134106120088 = 44.47039622446465
#       Subset: (1, 3, 4, 5), Total costs: 233.84730209614594
#         Subset without customer: {1, 4, 5}, Total costs: 177.2920507627102
#         Marginal contribution: 233.84730209614594 - 177.2920507627102 = 56.555251333435734
#       Subset: (1, 3, 4, 6), Total costs: 234.21030957373944
#         Subset without customer: {1, 4, 6}, Total costs: 177.02712179213282
#         Marginal contribution: 234.21030957373944 - 177.02712179213282 = 57.18318778160662
#       Subset: (1, 3, 5, 6), Total costs: 176.08332964419088
#         Subset without customer: {1, 5, 6}, Total costs: 101.75115768655945
#         Marginal contribution: 176.08332964419088 - 101.75115768655945 = 74.33217195763143
#       Subset: (2, 3, 4, 5), Total costs: 218.40391886851745
#         Subset without customer: {2, 4, 5}, Total costs: 129.4698696856647
#         Marginal contribution: 218.40391886851745 - 129.4698696856647 = 88.93404918285276
#       Subset: (2, 3, 4, 6), Total costs: 230.29647920170638
#         Subset without customer: {2, 4, 6}, Total costs: 182.50469854975717
#         Marginal contribution: 230.29647920170638 - 182.50469854975717 = 47.79178065194921
#       Subset: (2, 3, 5, 6), Total costs: 193.75566683730233
#         Subset without customer: {2, 5, 6}, Total costs: 145.96388618535312
#         Marginal contribution: 193.75566683730233 - 145.96388618535312 = 47.79178065194921
#       Subset: (3, 4, 5, 6), Total costs: 229.42423912537618
#         Subset without customer: {4, 5, 6}, Total costs: 168.91966691628505
#         Marginal contribution: 229.42423912537618 - 168.91966691628505 = 60.50457220909112
#       Subset: (1, 2, 3, 4, 5), Total costs: 234.93152036401636
#         Subset without customer: {1, 2, 4, 5}, Total costs: 190.9709205584092
#         Marginal contribution: 234.93152036401636 - 190.9709205584092 = 43.96059980560716
#       Subset: (1, 2, 3, 4, 6), Total costs: 235.29452784160986
#         Subset without customer: {1, 2, 4, 6}, Total costs: 190.82413161714518
#         Marginal contribution: 235.29452784160986 - 190.82413161714518 = 44.47039622446468
#       Subset: (1, 2, 3, 5, 6), Total costs: 198.7537154772058
#         Subset without customer: {1, 2, 5, 6}, Total costs: 154.3897141795889
#         Marginal contribution: 198.7537154772058 - 154.3897141795889 = 44.36400129761688
#       Subset: (1, 3, 4, 5, 6), Total costs: 234.4222877652797
#         Subset without customer: {1, 4, 5, 6}, Total costs: 177.34549491052084
#         Marginal contribution: 234.4222877652797 - 177.34549491052084 = 57.07679285475885
#       Subset: (2, 3, 4, 5, 6), Total costs: 230.5084573932466
#         Subset without customer: {2, 4, 5, 6}, Total costs: 182.71667674129742
#         Marginal contribution: 230.5084573932466 - 182.71667674129742 = 47.79178065194918
#       Subset: (1, 2, 3, 4, 5, 6), Total costs: 251.69440915430616
#         Subset without customer: {1, 2, 4, 5, 6}, Total costs: 191.14250473553318
#         Marginal contribution: 251.69440915430616 - 191.14250473553318 = 60.55190441877298
#    Shapley value: 83.53693538433564
#
#   - Customer: 4
#       Subset: (4,), Total costs: 84.23307172752116
#         Subset without customer: set(), Total costs: 0
#         Marginal contribution: 84.23307172752116 - 0 = 84.23307172752116
#       Subset: (1, 4), Total costs: 176.97367764432218
#         Subset without customer: {1}, Total costs: 100.8577988990377
#         Marginal contribution: 176.97367764432218 - 100.8577988990377 = 76.11587874528448
#       Subset: (2, 4), Total costs: 124.23494081379698
#         Subset without customer: {2}, Total costs: 87.48215025785268
#         Marginal contribution: 124.23494081379698 - 87.48215025785268 = 36.7527905559443
#       Subset: (3, 4), Total costs: 216.89219751856717
#         Subset without customer: {3}, Total costs: 158.55323939747836
#         Marginal contribution: 216.89219751856717 - 158.55323939747836 = 58.33895812108881
#       Subset: (4, 5), Total costs: 96.70655597855811
#         Subset without customer: {5}, Total costs: 16.399881312696333
#         Marginal contribution: 96.70655597855811 - 16.399881312696333 = 80.30667466586178
#       Subset: (4, 6), Total costs: 168.7076887247448
#         Subset without customer: {6}, Total costs: 93.21974642763116
#         Marginal contribution: 168.7076887247448 - 93.21974642763116 = 75.48794229711363
#       Subset: (1, 2, 4), Total costs: 190.6525474400212
#         Subset without customer: {1, 2}, Total costs: 153.8997568840769
#         Marginal contribution: 190.6525474400212 - 153.8997568840769 = 36.7527905559443
#       Subset: (1, 3, 4), Total costs: 233.52892897775791
#         Subset without customer: {1, 3}, Total costs: 175.1899708566691
#         Marginal contribution: 233.52892897775791 - 175.1899708566691 = 58.33895812108881
#       Subset: (1, 4, 5), Total costs: 177.2920507627102
#         Subset without customer: {1, 5}, Total costs: 101.17617201742571
#         Marginal contribution: 177.2920507627102 - 101.17617201742571 = 76.11587874528449
#       Subset: (1, 4, 6), Total costs: 177.02712179213282
#         Subset without customer: {1, 6}, Total costs: 101.5391794950192
#         Marginal contribution: 177.02712179213282 - 101.5391794950192 = 75.48794229711362
#       Subset: (2, 3, 4), Total costs: 217.9764157864376
#         Subset without customer: {2, 3}, Total costs: 181.22362523049327
#         Marginal contribution: 217.9764157864376 - 181.22362523049327 = 36.75279055594433
#       Subset: (2, 4, 5), Total costs: 129.4698696856647
#         Subset without customer: {2, 5}, Total costs: 92.7170791297204
#         Marginal contribution: 129.4698696856647 - 92.7170791297204 = 36.75279055594429
#       Subset: (2, 4, 6), Total costs: 182.50469854975717
#         Subset without customer: {2, 6}, Total costs: 145.7519079938129
#         Marginal contribution: 182.50469854975717 - 145.7519079938129 = 36.75279055594427
#       Subset: (3, 4, 5), Total costs: 217.319700600647
#         Subset without customer: {3, 5}, Total costs: 158.98074247955822
#         Marginal contribution: 217.319700600647 - 158.98074247955822 = 58.33895812108878
#       Subset: (3, 4, 6), Total costs: 229.21226093383595
#         Subset without customer: {3, 6}, Total costs: 170.87330281274714
#         Marginal contribution: 229.21226093383595 - 170.87330281274714 = 58.33895812108881
#       Subset: (4, 5, 6), Total costs: 168.91966691628505
#         Subset without customer: {5, 6}, Total costs: 93.43172461917142
#         Marginal contribution: 168.91966691628505 - 93.43172461917142 = 75.48794229711363
#       Subset: (1, 2, 3, 4), Total costs: 234.61314724562834
#         Subset without customer: {1, 2, 3}, Total costs: 197.86035668968404
#         Marginal contribution: 234.61314724562834 - 197.86035668968404 = 36.7527905559443
#       Subset: (1, 2, 4, 5), Total costs: 190.9709205584092
#         Subset without customer: {1, 2, 5}, Total costs: 154.2181300024649
#         Marginal contribution: 190.9709205584092 - 154.2181300024649 = 36.7527905559443
#       Subset: (1, 2, 4, 6), Total costs: 190.82413161714518
#         Subset without customer: {1, 2, 6}, Total costs: 154.07134106120088
#         Marginal contribution: 190.82413161714518 - 154.07134106120088 = 36.7527905559443
#       Subset: (1, 3, 4, 5), Total costs: 233.84730209614594
#         Subset without customer: {1, 3, 5}, Total costs: 175.50834397505716
#         Marginal contribution: 233.84730209614594 - 175.50834397505716 = 58.33895812108878
#       Subset: (1, 3, 4, 6), Total costs: 234.21030957373944
#         Subset without customer: {1, 3, 6}, Total costs: 175.87135145265063
#         Marginal contribution: 234.21030957373944 - 175.87135145265063 = 58.33895812108881
#       Subset: (1, 4, 5, 6), Total costs: 177.34549491052084
#         Subset without customer: {1, 5, 6}, Total costs: 101.75115768655945
#         Marginal contribution: 177.34549491052084 - 101.75115768655945 = 75.59433722396139
#       Subset: (2, 3, 4, 5), Total costs: 218.40391886851745
#         Subset without customer: {2, 3, 5}, Total costs: 181.65112831257312
#         Marginal contribution: 218.40391886851745 - 181.65112831257312 = 36.75279055594433
#       Subset: (2, 3, 4, 6), Total costs: 230.29647920170638
#         Subset without customer: {2, 3, 6}, Total costs: 193.54368864576207
#         Marginal contribution: 230.29647920170638 - 193.54368864576207 = 36.7527905559443
#       Subset: (2, 4, 5, 6), Total costs: 182.71667674129742
#         Subset without customer: {2, 5, 6}, Total costs: 145.96388618535312
#         Marginal contribution: 182.71667674129742 - 145.96388618535312 = 36.7527905559443
#       Subset: (3, 4, 5, 6), Total costs: 229.42423912537618
#         Subset without customer: {3, 5, 6}, Total costs: 171.0852810042874
#         Marginal contribution: 229.42423912537618 - 171.0852810042874 = 58.33895812108878
#       Subset: (1, 2, 3, 4, 5), Total costs: 234.93152036401636
#         Subset without customer: {1, 2, 3, 5}, Total costs: 198.17872980807203
#         Marginal contribution: 234.93152036401636 - 198.17872980807203 = 36.75279055594433
#       Subset: (1, 2, 3, 4, 6), Total costs: 235.29452784160986
#         Subset without customer: {1, 2, 3, 6}, Total costs: 198.54173728566553
#         Marginal contribution: 235.29452784160986 - 198.54173728566553 = 36.75279055594433
#       Subset: (1, 2, 4, 5, 6), Total costs: 191.14250473553318
#         Subset without customer: {1, 2, 5, 6}, Total costs: 154.3897141795889
#         Marginal contribution: 191.14250473553318 - 154.3897141795889 = 36.75279055594427
#       Subset: (1, 3, 4, 5, 6), Total costs: 234.4222877652797
#         Subset without customer: {1, 3, 5, 6}, Total costs: 176.08332964419088
#         Marginal contribution: 234.4222877652797 - 176.08332964419088 = 58.33895812108881
#       Subset: (2, 3, 4, 5, 6), Total costs: 230.5084573932466
#         Subset without customer: {2, 3, 5, 6}, Total costs: 193.75566683730233
#         Marginal contribution: 230.5084573932466 - 193.75566683730233 = 36.75279055594427
#       Subset: (1, 2, 3, 4, 5, 6), Total costs: 251.69440915430616
#         Subset without customer: {1, 2, 3, 5, 6}, Total costs: 198.7537154772058
#         Marginal contribution: 251.69440915430616 - 198.7537154772058 = 52.94069367710037
#    Shapley value: 57.61150230593303
#
#   - Customer: 5
#       Subset: (5,), Total costs: 16.399881312696333
#         Subset without customer: set(), Total costs: 0
#         Marginal contribution: 16.399881312696333 - 0 = 16.399881312696333
#       Subset: (1, 5), Total costs: 101.17617201742571
#         Subset without customer: {1}, Total costs: 100.8577988990377
#         Marginal contribution: 101.17617201742571 - 100.8577988990377 = 0.31837311838800986
#       Subset: (2, 5), Total costs: 92.7170791297204
#         Subset without customer: {2}, Total costs: 87.48215025785268
#         Marginal contribution: 92.7170791297204 - 87.48215025785268 = 5.234928871867723
#       Subset: (3, 5), Total costs: 158.98074247955822
#         Subset without customer: {3}, Total costs: 158.55323939747836
#         Marginal contribution: 158.98074247955822 - 158.55323939747836 = 0.427503082079852
#       Subset: (4, 5), Total costs: 96.70655597855811
#         Subset without customer: {4}, Total costs: 84.23307172752116
#         Marginal contribution: 96.70655597855811 - 84.23307172752116 = 12.47348425103695
#       Subset: (5, 6), Total costs: 93.43172461917142
#         Subset without customer: {6}, Total costs: 93.21974642763116
#         Marginal contribution: 93.43172461917142 - 93.21974642763116 = 0.2119781915402541
#       Subset: (1, 2, 5), Total costs: 154.2181300024649
#         Subset without customer: {1, 2}, Total costs: 153.8997568840769
#         Marginal contribution: 154.2181300024649 - 153.8997568840769 = 0.31837311838799565
#       Subset: (1, 3, 5), Total costs: 175.50834397505716
#         Subset without customer: {1, 3}, Total costs: 175.1899708566691
#         Marginal contribution: 175.50834397505716 - 175.1899708566691 = 0.3183731183880525
#       Subset: (1, 4, 5), Total costs: 177.2920507627102
#         Subset without customer: {1, 4}, Total costs: 176.97367764432218
#         Marginal contribution: 177.2920507627102 - 176.97367764432218 = 0.31837311838802407
#       Subset: (1, 5, 6), Total costs: 101.75115768655945
#         Subset without customer: {1, 6}, Total costs: 101.5391794950192
#         Marginal contribution: 101.75115768655945 - 101.5391794950192 = 0.2119781915402541
#       Subset: (2, 3, 5), Total costs: 181.65112831257312
#         Subset without customer: {2, 3}, Total costs: 181.22362523049327
#         Marginal contribution: 181.65112831257312 - 181.22362523049327 = 0.427503082079852
#       Subset: (2, 4, 5), Total costs: 129.4698696856647
#         Subset without customer: {2, 4}, Total costs: 124.23494081379698
#         Marginal contribution: 129.4698696856647 - 124.23494081379698 = 5.234928871867709
#       Subset: (2, 5, 6), Total costs: 145.96388618535312
#         Subset without customer: {2, 6}, Total costs: 145.7519079938129
#         Marginal contribution: 145.96388618535312 - 145.7519079938129 = 0.21197819154022568
#       Subset: (3, 4, 5), Total costs: 217.319700600647
#         Subset without customer: {3, 4}, Total costs: 216.89219751856717
#         Marginal contribution: 217.319700600647 - 216.89219751856717 = 0.42750308207982357
#       Subset: (3, 5, 6), Total costs: 171.0852810042874
#         Subset without customer: {3, 6}, Total costs: 170.87330281274714
#         Marginal contribution: 171.0852810042874 - 170.87330281274714 = 0.2119781915402541
#       Subset: (4, 5, 6), Total costs: 168.91966691628505
#         Subset without customer: {4, 6}, Total costs: 168.7076887247448
#         Marginal contribution: 168.91966691628505 - 168.7076887247448 = 0.2119781915402541
#       Subset: (1, 2, 3, 5), Total costs: 198.17872980807203
#         Subset without customer: {1, 2, 3}, Total costs: 197.86035668968404
#         Marginal contribution: 198.17872980807203 - 197.86035668968404 = 0.31837311838799565
#       Subset: (1, 2, 4, 5), Total costs: 190.9709205584092
#         Subset without customer: {1, 2, 4}, Total costs: 190.6525474400212
#         Marginal contribution: 190.9709205584092 - 190.6525474400212 = 0.31837311838799565
#       Subset: (1, 2, 5, 6), Total costs: 154.3897141795889
#         Subset without customer: {1, 2, 6}, Total costs: 154.07134106120088
#         Marginal contribution: 154.3897141795889 - 154.07134106120088 = 0.31837311838802407
#       Subset: (1, 3, 4, 5), Total costs: 233.84730209614594
#         Subset without customer: {1, 3, 4}, Total costs: 233.52892897775791
#         Marginal contribution: 233.84730209614594 - 233.52892897775791 = 0.31837311838802407
#       Subset: (1, 3, 5, 6), Total costs: 176.08332964419088
#         Subset without customer: {1, 3, 6}, Total costs: 175.87135145265063
#         Marginal contribution: 176.08332964419088 - 175.87135145265063 = 0.2119781915402541
#       Subset: (1, 4, 5, 6), Total costs: 177.34549491052084
#         Subset without customer: {1, 4, 6}, Total costs: 177.02712179213282
#         Marginal contribution: 177.34549491052084 - 177.02712179213282 = 0.31837311838802407
#       Subset: (2, 3, 4, 5), Total costs: 218.40391886851745
#         Subset without customer: {2, 3, 4}, Total costs: 217.9764157864376
#         Marginal contribution: 218.40391886851745 - 217.9764157864376 = 0.427503082079852
#       Subset: (2, 3, 5, 6), Total costs: 193.75566683730233
#         Subset without customer: {2, 3, 6}, Total costs: 193.54368864576207
#         Marginal contribution: 193.75566683730233 - 193.54368864576207 = 0.2119781915402541
#       Subset: (2, 4, 5, 6), Total costs: 182.71667674129742
#         Subset without customer: {2, 4, 6}, Total costs: 182.50469854975717
#         Marginal contribution: 182.71667674129742 - 182.50469854975717 = 0.2119781915402541
#       Subset: (3, 4, 5, 6), Total costs: 229.42423912537618
#         Subset without customer: {3, 4, 6}, Total costs: 229.21226093383595
#         Marginal contribution: 229.42423912537618 - 229.21226093383595 = 0.21197819154022568
#       Subset: (1, 2, 3, 4, 5), Total costs: 234.93152036401636
#         Subset without customer: {1, 2, 3, 4}, Total costs: 234.61314724562834
#         Marginal contribution: 234.93152036401636 - 234.61314724562834 = 0.31837311838802407
#       Subset: (1, 2, 3, 5, 6), Total costs: 198.7537154772058
#         Subset without customer: {1, 2, 3, 6}, Total costs: 198.54173728566553
#         Marginal contribution: 198.7537154772058 - 198.54173728566553 = 0.2119781915402541
#       Subset: (1, 2, 4, 5, 6), Total costs: 191.14250473553318
#         Subset without customer: {1, 2, 4, 6}, Total costs: 190.82413161714518
# ...
#         Marginal contribution: 251.69440915430616 - 235.29452784160986 = 16.399881312696294
#    Shapley value: 6.310596191734645
#
#   - Customer: 6
#       Subset: (6,), Total costs: 93.21974642763116
#         Subset without customer: set(), Total costs: 0
#         Marginal contribution: 93.21974642763116 - 0 = 93.21974642763116
#       Subset: (1, 6), Total costs: 101.5391794950192
#         Subset without customer: {1}, Total costs: 100.8577988990377
#         Marginal contribution: 101.5391794950192 - 100.8577988990377 = 0.6813805959814943
#       Subset: (2, 6), Total costs: 145.7519079938129
#         Subset without customer: {2}, Total costs: 87.48215025785268
#         Marginal contribution: 145.7519079938129 - 87.48215025785268 = 58.26975773596021
#       Subset: (3, 6), Total costs: 170.87330281274714
#         Subset without customer: {3}, Total costs: 158.55323939747836
#         Marginal contribution: 170.87330281274714 - 158.55323939747836 = 12.320063415268777
#       Subset: (4, 6), Total costs: 168.7076887247448
#         Subset without customer: {4}, Total costs: 84.23307172752116
#         Marginal contribution: 168.7076887247448 - 84.23307172752116 = 84.47461699722363
#       Subset: (5, 6), Total costs: 93.43172461917142
#         Subset without customer: {5}, Total costs: 16.399881312696333
#         Marginal contribution: 93.43172461917142 - 16.399881312696333 = 77.03184330647508
#       Subset: (1, 2, 6), Total costs: 154.07134106120088
#         Subset without customer: {1, 2}, Total costs: 153.8997568840769
#         Marginal contribution: 154.07134106120088 - 153.8997568840769 = 0.17158417712397522
#       Subset: (1, 3, 6), Total costs: 175.87135145265063
#         Subset without customer: {1, 3}, Total costs: 175.1899708566691
#         Marginal contribution: 175.87135145265063 - 175.1899708566691 = 0.6813805959815227
#       Subset: (1, 4, 6), Total costs: 177.02712179213282
#         Subset without customer: {1, 4}, Total costs: 176.97367764432218
#         Marginal contribution: 177.02712179213282 - 176.97367764432218 = 0.05344414781063733
#       Subset: (1, 5, 6), Total costs: 101.75115768655945
#         Subset without customer: {1, 5}, Total costs: 101.17617201742571
#         Marginal contribution: 101.75115768655945 - 101.17617201742571 = 0.5749856691337385
#       Subset: (2, 3, 6), Total costs: 193.54368864576207
#         Subset without customer: {2, 3}, Total costs: 181.22362523049327
#         Marginal contribution: 193.54368864576207 - 181.22362523049327 = 12.320063415268805
#       Subset: (2, 4, 6), Total costs: 182.50469854975717
#         Subset without customer: {2, 4}, Total costs: 124.23494081379698
#         Marginal contribution: 182.50469854975717 - 124.23494081379698 = 58.269757735960184
#       Subset: (2, 5, 6), Total costs: 145.96388618535312
#         Subset without customer: {2, 5}, Total costs: 92.7170791297204
#         Marginal contribution: 145.96388618535312 - 92.7170791297204 = 53.246807055632715
#       Subset: (3, 4, 6), Total costs: 229.21226093383595
#         Subset without customer: {3, 4}, Total costs: 216.89219751856717
#         Marginal contribution: 229.21226093383595 - 216.89219751856717 = 12.320063415268777
#       Subset: (3, 5, 6), Total costs: 171.0852810042874
#         Subset without customer: {3, 5}, Total costs: 158.98074247955822
#         Marginal contribution: 171.0852810042874 - 158.98074247955822 = 12.104538524729179
#       Subset: (4, 5, 6), Total costs: 168.91966691628505
#         Subset without customer: {4, 5}, Total costs: 96.70655597855811
#         Marginal contribution: 168.91966691628505 - 96.70655597855811 = 72.21311093772694
#       Subset: (1, 2, 3, 6), Total costs: 198.54173728566553
#         Subset without customer: {1, 2, 3}, Total costs: 197.86035668968404
#         Marginal contribution: 198.54173728566553 - 197.86035668968404 = 0.6813805959814943
#       Subset: (1, 2, 4, 6), Total costs: 190.82413161714518
#         Subset without customer: {1, 2, 4}, Total costs: 190.6525474400212
#         Marginal contribution: 190.82413161714518 - 190.6525474400212 = 0.17158417712397522
#       Subset: (1, 2, 5, 6), Total costs: 154.3897141795889
#         Subset without customer: {1, 2, 5}, Total costs: 154.2181300024649
#         Marginal contribution: 154.3897141795889 - 154.2181300024649 = 0.17158417712400365
#       Subset: (1, 3, 4, 6), Total costs: 234.21030957373944
#         Subset without customer: {1, 3, 4}, Total costs: 233.52892897775791
#         Marginal contribution: 234.21030957373944 - 233.52892897775791 = 0.6813805959815227
#       Subset: (1, 3, 5, 6), Total costs: 176.08332964419088
#         Subset without customer: {1, 3, 5}, Total costs: 175.50834397505716
#         Marginal contribution: 176.08332964419088 - 175.50834397505716 = 0.5749856691337243
#       Subset: (1, 4, 5, 6), Total costs: 177.34549491052084
#         Subset without customer: {1, 4, 5}, Total costs: 177.2920507627102
#         Marginal contribution: 177.34549491052084 - 177.2920507627102 = 0.05344414781063733
#       Subset: (2, 3, 4, 6), Total costs: 230.29647920170638
#         Subset without customer: {2, 3, 4}, Total costs: 217.9764157864376
#         Marginal contribution: 230.29647920170638 - 217.9764157864376 = 12.320063415268777
#       Subset: (2, 3, 5, 6), Total costs: 193.75566683730233
#         Subset without customer: {2, 3, 5}, Total costs: 181.65112831257312
#         Marginal contribution: 193.75566683730233 - 181.65112831257312 = 12.104538524729207
#       Subset: (2, 4, 5, 6), Total costs: 182.71667674129742
#         Subset without customer: {2, 4, 5}, Total costs: 129.4698696856647
#         Marginal contribution: 182.71667674129742 - 129.4698696856647 = 53.24680705563273
#       Subset: (3, 4, 5, 6), Total costs: 229.42423912537618
#         Subset without customer: {3, 4, 5}, Total costs: 217.319700600647
#         Marginal contribution: 229.42423912537618 - 217.319700600647 = 12.104538524729179
#       Subset: (1, 2, 3, 4, 6), Total costs: 235.29452784160986
#         Subset without customer: {1, 2, 3, 4}, Total costs: 234.61314724562834
#         Marginal contribution: 235.29452784160986 - 234.61314724562834 = 0.6813805959815227
#       Subset: (1, 2, 3, 5, 6), Total costs: 198.7537154772058
#         Subset without customer: {1, 2, 3, 5}, Total costs: 198.17872980807203
#         Marginal contribution: 198.7537154772058 - 198.17872980807203 = 0.5749856691337527
#       Subset: (1, 2, 4, 5, 6), Total costs: 191.14250473553318
#         Subset without customer: {1, 2, 4, 5}, Total costs: 190.9709205584092
#         Marginal contribution: 191.14250473553318 - 190.9709205584092 = 0.17158417712397522
#       Subset: (1, 3, 4, 5, 6), Total costs: 234.4222877652797
#         Subset without customer: {1, 3, 4, 5}, Total costs: 233.84730209614594
#         Marginal contribution: 234.4222877652797 - 233.84730209614594 = 0.5749856691337527
#       Subset: (2, 3, 4, 5, 6), Total costs: 230.5084573932466
#         Subset without customer: {2, 3, 4, 5}, Total costs: 218.40391886851745
#         Marginal contribution: 230.5084573932466 - 218.40391886851745 = 12.10453852472915
#       Subset: (1, 2, 3, 4, 5, 6), Total costs: 251.69440915430616
#         Subset without customer: {1, 2, 3, 4, 5}, Total costs: 234.93152036401636
#         Marginal contribution: 251.69440915430616 - 234.93152036401636 = 16.762888790289793
#    Shapley value: 31.794377801856402
#    Instance ID  Number Customers          X          Y  Vehicle Capacity  \
# 0       600000                 6  50.972432  22.758978              11.0
# 1       600000                 6  94.706549  47.866763              11.0
# 2       600000                 6  37.282589  64.302568              11.0
# 3       600000                 6  88.004425  92.854727              11.0
# 4       600000                 6  11.079519  36.262980              11.0
# 5       600000                 6  56.817199  28.510302              11.0
# 6       600000                 6  90.206480  47.921843              11.0
#
#    Demand  Total Demand    X Depot    Y Depot    Savings  Total Costs  \
# 0     0.0          12.0  50.972432  22.758978        NaN   251.694409
# 1     1.0          12.0  50.972432  22.758978   4.998049   251.694409
# 2     5.0          12.0  50.972432  22.758978   1.084218   251.694409
# 3     1.0          12.0  50.972432  22.758978  43.960600   251.694409
# 4     1.0          12.0  50.972432  22.758978  36.752791   251.694409
# 5     3.0          12.0  50.972432  22.758978  16.399881   251.694409
# 6     1.0          12.0  50.972432  22.758978   0.681381   251.694409
#
#    Marginal Costs  Shapley Value
# 0             NaN       0.000000
# 1       21.185952      37.962230
# 2       17.272121      34.478768
# 3       60.551904      83.536935
# 4       52.940694      57.611502
# 5       16.399881       6.310596
# 6       16.762889      31.794378
# ############### RATIO FEATURES ###############
# No ratio features:
#  ['10th CCD' '5th CCD' '6th CCD' '7th CCD' '8th CCD' '9th CCD' 'Cluster'
#  'Cluster Size' 'Core Point' 'Correlation' 'Instance ID' 'Number Clusters'
#  'Number Customers' 'Number Outliers' 'Outlier' 'Shapley Value'
#  'Skewness X' 'Skewness Y' 'Total Costs' 'Total Demand' 'Vehicle Capacity'
#  'X' 'X Centroid' 'X Depot' 'X Max' 'X Mean' 'X Min' 'X Std' 'Y'
#  'Y Centroid' 'Y Depot' 'Y Max' 'Y Mean' 'Y Min' 'Y Std']
#    Instance ID  Number Customers          X          Y  Vehicle Capacity  \
# 0       600000                 6  50.972432  22.758978              11.0
# 1       600000                 6  94.706549  47.866763              11.0
# 2       600000                 6  37.282589  64.302568              11.0
# 3       600000                 6  88.004425  92.854727              11.0
# 4       600000                 6  11.079519  36.262980              11.0
# 5       600000                 6  56.817199  28.510302              11.0
# 6       600000                 6  90.206480  47.921843              11.0
#
#    Demand  Total Demand    X Depot    Y Depot  Demand Ratio  ...  \
# 0     0.0          12.0  50.972432  22.758978           NaN  ...
# 1     1.0          12.0  50.972432  22.758978           0.5  ...
# 2     5.0          12.0  50.972432  22.758978           2.5  ...
# 3     1.0          12.0  50.972432  22.758978           0.5  ...
# 4     1.0          12.0  50.972432  22.758978           0.5  ...
# 5     3.0          12.0  50.972432  22.758978           1.5  ...
# 6     1.0          12.0  50.972432  22.758978           0.5  ...
#
#    Gravity Center Distance Ratio  Centroid Distance Ratio  \
# 0                            NaN                      NaN
# 1                       0.896861                 1.006400
# 2                       0.785902                 1.243845
# 3                       1.315565                 0.000000
# 4                       1.524363                 1.243845
# 5                       0.704631                 1.753202
# 6                       0.772679                 0.752708
#
#    Centroid Distance To Depot Ratio  Distance To Closest Other Cluster Ratio  \
# 0                               NaN                                      NaN
# 1                          0.804325                                 1.244112
# 2                          0.882644                                 0.849325
# 3                          1.821735                                 0.937031
# 4                          0.882644                                 0.966259
# 5                          0.804325                                 0.849325
# 6                          0.804325                                 1.153947
#
#    Distance To Closest Other Centroid Ratio  Cluster Area Ratio  \
# 0                                       NaN                 NaN
# 1                                  1.222027            1.464772
# 2                                  0.847911            0.802193
# 3                                  0.899727            0.001299
# 4                                  1.206829            0.802193
# 5                                  0.679394            1.464772
# 6                                  1.144112            1.464772
#
#    Cluster Density Ratio  Cluster Demand Ratio  Savings Ratio  \
# 0                    NaN                   NaN            NaN
# 1               0.015737              1.071429       0.288691
# 2               0.019156              1.285714       0.062625
# 3               5.914477              0.214286       2.539194
# 4               0.019156              1.285714       2.122866
# 5               0.015737              1.071429       0.947268
# 6               0.015737              1.071429       0.039357
#
#    Marginal Costs Ratio
# 0                   NaN
# 1              0.686691
# 2              0.559834
# 3              1.962642
# 4              1.715943
# 5              0.531562
# 6              0.543328
#
# [7 rows x 26 columns]
# ############### FINAL INSTANCE ###############
#    Instance ID  Number Customers          X          Y  Vehicle Capacity  \
# 1       600000                 6  94.706549  47.866763              11.0
# 2       600000                 6  37.282589  64.302568              11.0
# 3       600000                 6  88.004425  92.854727              11.0
# 4       600000                 6  11.079519  36.262980              11.0
# 5       600000                 6  56.817199  28.510302              11.0
# 6       600000                 6  90.206480  47.921843              11.0
#
#    Demand  Total Demand    X Depot    Y Depot  Depot Distance  ...  \
# 1     1.0          12.0  50.972432  22.758978       50.428899  ...
# 2     5.0          12.0  50.972432  22.758978       43.741075  ...
# 3     1.0          12.0  50.972432  22.758978       79.276620  ...
# 4     1.0          12.0  50.972432  22.758978       42.116536  ...
# 5     3.0          12.0  50.972432  22.758978        8.199941  ...
# 6     1.0          12.0  50.972432  22.758978       46.609873  ...
#
#    Centroid Distance To Depot Ratio  Distance To Closest Other Cluster Ratio  \
# 1                          0.804325                                 1.244112
# 2                          0.882644                                 0.849325
# 3                          1.821735                                 0.937031
# 4                          0.882644                                 0.966259
# 5                          0.804325                                 0.849325
# 6                          0.804325                                 1.153947
#
#    Distance To Closest Other Centroid Ratio  Cluster Area Ratio  \
# 1                                  1.222027            1.464772
# 2                                  0.847911            0.802193
# 3                                  0.899727            0.001299
# 4                                  1.206829            0.802193
# 5                                  0.679394            1.464772
# 6                                  1.144112            1.464772
#
#    Cluster Density Ratio  Cluster Demand Ratio  Savings Ratio  \
# 1               0.015737              1.071429       0.288691
# 2               0.019156              1.285714       0.062625
# 3               5.914477              0.214286       2.539194
# 4               0.019156              1.285714       2.122866
# 5               0.015737              1.071429       0.947268
# 6               0.015737              1.071429       0.039357
#
#    Marginal Costs Ratio  Shapley Value  Customer Cluster Demand Ratio
# 1              0.686691      37.962230                            0.6
# 2              0.559834      34.478768                       1.666667
# 3              1.962642      83.536935                            1.0
# 4              1.715943      57.611502                       0.333333
# 5              0.531562       6.310596                            1.8
# 6              0.543328      31.794378                            0.6
#
# [6 rows x 70 columns]
# File saved successfully!
