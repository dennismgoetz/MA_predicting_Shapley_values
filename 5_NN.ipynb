# %%
import time
import pickle
import pandas as pd
import numpy as np

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.neural_network import MLPRegressor

# Import helperfunctions
from ML_functions import fun_load_data, fun_preprocessing, fun_fit_tuning
from ML_functions import fun_convert_time
from ML_functions import fun_scaled_neg_MAPE, fun_tuning_results, fun_scores

# Load optimization_problem ('TSP' or 'CVRP') and the size of the train set
with open('settings.pkl', 'rb') as file:
    settings = pickle.load(file)
optimization_problem, train_size = settings['optimization_problem'], settings['train_size']

# Assign string 'TSP' or 'CVRP' to the following variable to define the optimization problem
optimization_problem = 'TSP'
train_size = 0.7

# Load data
data = fun_load_data(optimization_problem)
X, y, train_data = fun_preprocessing(data)

# Create a train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=train_size, random_state=42)

# %% [markdown]
# # **Neural Network - Multi Layer Perceptron**

# %%
# Define a pipeline
pipe = make_pipeline(StandardScaler(),
                     MLPRegressor(activation='relu', learning_rate='adaptive', 
                                  max_iter=1000, shuffle=True, random_state=42))

# Define parameter grid
param_grid = {'mlpregressor__hidden_layer_sizes': [(100, 100), (50, 50, 50), (100, 100, 100)],
              'mlpregressor__alpha': [0.05, 0.1, 0.5, 1],
              'mlpregressor__solver': ['sgd', 'adam', 'lbfgs'],
              'mlpregressor__batch_size': ['auto', 32, 64]}

# Grid search
grid_search = GridSearchCV(estimator=pipe, param_grid=param_grid, cv=3, 
                           scoring=fun_scaled_neg_MAPE, verbose=True, n_jobs=-1)
fit_time = fun_fit_tuning(search_method=grid_search, X_train=X_train, y_train=y_train, file_name=optimization_problem + '_NN_GS')

# Estimate model performance with cross validation on the train set (scoring: MAPE and RMSE)
model_results_dict = fun_scores(model=grid_search, X_train=X_train, y_train=y_train)

# View grid search CV scores of all parameter combinations
results_df = fun_tuning_results(search_method=grid_search, search_space=param_grid)

# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# Tuning fit time: 5h, 32m
# Out:
# CV MAPE (scaled) train data:  2.9062 %
#
# Best model / parameter combination:
# {'mlpregressor__alpha': 0.1,
#  'mlpregressor__batch_size': 32,
#  'mlpregressor__hidden_layer_sizes': (100, 100, 100),
#  'mlpregressor__solver': 'sgd'}
# Cross validation scores of different parameter combinations:
#    param_mlpregressor__hidden_layer_sizes param_mlpregressor__alpha  \
# 0                         (100, 100, 100)                       0.1
# 1                         (100, 100, 100)                      0.05
# 2                         (100, 100, 100)                       0.5
# 3                              (100, 100)                       0.1
# 4                            (50, 50, 50)                      0.05
# 5                            (50, 50, 50)                       0.1
# 6                              (100, 100)                      0.05
# 7                              (100, 100)                       0.1
# 8                         (100, 100, 100)                       0.1
# 9                         (100, 100, 100)                      0.05
# 10                           (50, 50, 50)                      0.05
# 11                        (100, 100, 100)                         1
# 12                        (100, 100, 100)                         1
# 13                        (100, 100, 100)                      0.05
# 14                        (100, 100, 100)                      0.05
# 15                        (100, 100, 100)                      0.05
# 16                             (100, 100)                       0.5
# 17                        (100, 100, 100)                         1
# 18                        (100, 100, 100)                         1
# 19                        (100, 100, 100)                         1
# 20                           (50, 50, 50)                       0.1
# 21                        (100, 100, 100)                       0.1
# 22                        (100, 100, 100)                       0.1
# 23                        (100, 100, 100)                       0.1
# 24                        (100, 100, 100)                       0.5
# 25                        (100, 100, 100)                       0.5
# 26                        (100, 100, 100)                       0.5
# 27                        (100, 100, 100)                       0.5
# 28                             (100, 100)                      0.05
# 29                           (50, 50, 50)                       0.5
# 30                        (100, 100, 100)                       0.5
# 31                             (100, 100)                       0.1
# 32                             (100, 100)                      0.05
# 33                             (100, 100)                       0.5
# 34                        (100, 100, 100)                      0.05
# 35                             (100, 100)                         1
# 36                        (100, 100, 100)                       0.1
# 37                             (100, 100)                      0.05
# 38                             (100, 100)                      0.05
# 39                             (100, 100)                      0.05
# 40                        (100, 100, 100)                       0.1
# 41                             (100, 100)                       0.1
# 42                             (100, 100)                       0.1
# 43                             (100, 100)                       0.1
# 44                        (100, 100, 100)                      0.05
# 45                             (100, 100)                         1
# 46                             (100, 100)                         1
# 47                             (100, 100)                         1
# 48                             (100, 100)                       0.5
# 49                             (100, 100)                       0.5
# 50                             (100, 100)                       0.5
# 51                        (100, 100, 100)                         1
# 52                           (50, 50, 50)                         1
# 53                        (100, 100, 100)                      0.05
# 54                           (50, 50, 50)                      0.05
# 55                           (50, 50, 50)                       0.5
# 56                           (50, 50, 50)                       0.5
# 57                        (100, 100, 100)                       0.5
# 58                           (50, 50, 50)                         1
# 59                           (50, 50, 50)                       0.1
#
#    param_mlpregressor__solver param_mlpregressor__batch_size  mean_test_score  \
# 0                         sgd                             32        -0.029062
# 1                         sgd                             32        -0.029315
# 2                         sgd                             64        -0.029933
# 3                         sgd                             32        -0.030052
# 4                         sgd                             32        -0.030071
# 5                         sgd                             32        -0.030199
# 6                         sgd                             32        -0.030222
# 7                         sgd                             64        -0.030539
# 8                         sgd                             64        -0.030586
# 9                         sgd                             64        -0.031192
# 10                        sgd                             64        -0.031449
# 11                        sgd                             64        -0.031477
# 12                        sgd                           auto        -0.031504
# 13                      lbfgs                           auto        -0.031507
# 14                      lbfgs                             64        -0.031507
# 15                      lbfgs                             32        -0.031507
# 16                        sgd                           auto        -0.031570
# 17                      lbfgs                           auto        -0.031620
# 18                      lbfgs                             32        -0.031620
# 19                      lbfgs                             64        -0.031620
# 20                        sgd                             64        -0.031628
# 21                      lbfgs                             32        -0.031671
# 22                      lbfgs                             64        -0.031671
# 23                      lbfgs                           auto        -0.031671
# 24                        sgd                             32        -0.031677
# 25                      lbfgs                           auto        -0.031788
# 26                      lbfgs                             64        -0.031788
# 27                      lbfgs                             32        -0.031788
# 28                        sgd                             64        -0.031971
# 29                        sgd                             64        -0.032058
# 30                        sgd                           auto        -0.032121
# 31                        sgd                           auto        -0.032293
# 32                        sgd                           auto        -0.032422
# 33                        sgd                             64        -0.032587
# 34                       adam                             32        -0.032756
# 35                        sgd                           auto        -0.032855
# 36                        sgd                           auto        -0.032883
# 37                      lbfgs                             32        -0.033085
# 38                      lbfgs                           auto        -0.033085
# 39                      lbfgs                             64        -0.033085
# 40                       adam                             64        -0.033086
# 41                      lbfgs                             32        -0.033100
# 42                      lbfgs                           auto        -0.033100
# 43                      lbfgs                             64        -0.033100
# 44                        sgd                           auto        -0.033139
# 45                      lbfgs                             32        -0.033240
# 46                      lbfgs                           auto        -0.033240
# 47                      lbfgs                             64        -0.033240
# 48                      lbfgs                             32        -0.033241
# 49                      lbfgs                           auto        -0.033241
# 50                      lbfgs                             64        -0.033241
# 51                       adam                           auto        -0.033338
# 52                        sgd                             64        -0.033365
# 53                       adam                             64        -0.033395
# 54                        sgd                           auto        -0.033449
# 55                        sgd                           auto        -0.033507
# 56                        sgd                             32        -0.033631
# 57                       adam                           auto        -0.033700
# 58                        sgd                           auto        -0.033720
# 59                      lbfgs                             32        -0.033723
#
#    converted_mean_fit_time
# 0                 23m, 37s
# 1                 29m, 30s
# 2                 13m, 14s
# 3                 13m, 38s
# 4                 12m, 57s
# 5                 13m, 12s
# 6                  14m, 7s
# 7                  9m, 15s
# 8                 21m, 29s
# 9                 20m, 26s
# 10                 8m, 24s
# 11                10m, 41s
# 12                11m, 11s
# 13                20m, 22s
# 14                20m, 38s
# 15                19m, 58s
# 16                 6m, 54s
# 17                19m, 35s
# 18                19m, 15s
# 19                13m, 27s
# 20                 7m, 38s
# 21                19m, 14s
# 22                 20m, 9s
# 23                 20m, 6s
# 24                18m, 55s
# 25                20m, 12s
# 26                20m, 35s
# 27                 20m, 4s
# 28                 9m, 37s
# 29                 7m, 39s
# 30                14m, 37s
# 31                 8m, 28s
# 32                  8m, 5s
# 33                  8m, 0s
# 34                17m, 58s
# 35                 4m, 53s
# 36                14m, 41s
# 37                12m, 15s
# 38                 13m, 6s
# 39                12m, 25s
# 40                16m, 51s
# 41                 12m, 2s
# 42                13m, 24s
# 43                11m, 35s
# 44                19m, 19s
# 45                 12m, 9s
# 46                 13m, 6s
# 47                11m, 58s
# 48                11m, 53s
# 49                12m, 30s
# 50                12m, 45s
# 51                 9m, 23s
# 52                 6m, 24s
# 53                13m, 49s
# 54                 5m, 24s
# 55                 6m, 57s
# 56                10m, 31s
# 57                 7m, 59s
# 58                 5m, 15s
# 59                 8m, 20s
#     param_mlpregressor__hidden_layer_sizes param_mlpregressor__alpha  \
# 60                            (50, 50, 50)                       0.1
# 61                            (50, 50, 50)                       0.1
# 62                            (50, 50, 50)                       0.5
# 63                            (50, 50, 50)                       0.5
# 64                            (50, 50, 50)                       0.5
# 65                            (50, 50, 50)                      0.05
# 66                            (50, 50, 50)                      0.05
# 67                            (50, 50, 50)                      0.05
# 68                            (50, 50, 50)                       0.1
# 69                            (50, 50, 50)                         1
# 70                            (50, 50, 50)                         1
# 71                            (50, 50, 50)                         1
# 72                            (50, 50, 50)                       0.1
# 73                         (100, 100, 100)                       0.1
# 74                              (100, 100)                         1
# 75                              (100, 100)                       0.5
# 76                         (100, 100, 100)                       0.1
# 77                         (100, 100, 100)                         1
# 78                              (100, 100)                       0.1
# 79                            (50, 50, 50)                      0.05
# 80                              (100, 100)                       0.1
# 81                              (100, 100)                       0.5
# 82                              (100, 100)                       0.1
# 83                         (100, 100, 100)                      0.05
# 84                         (100, 100, 100)                       0.5
# 85                              (100, 100)                      0.05
# 86                              (100, 100)                         1
# 87                            (50, 50, 50)                      0.05
# 88                            (50, 50, 50)                      0.05
# 89                            (50, 50, 50)                       0.1
# 90                            (50, 50, 50)                       0.5
# 91                              (100, 100)                      0.05
# 92                         (100, 100, 100)                         1
# 93                            (50, 50, 50)                       0.1
# 94                              (100, 100)                      0.05
# 95                              (100, 100)                       0.5
# 96                            (50, 50, 50)                         1
# 97                              (100, 100)                         1
# 98                         (100, 100, 100)                       0.5
# 99                            (50, 50, 50)                         1
# 100                           (50, 50, 50)                       0.5
# 101                             (100, 100)                       0.5
# 102                           (50, 50, 50)                         1
# 103                             (100, 100)                         1
# 104                           (50, 50, 50)                         1
# 105                           (50, 50, 50)                       0.5
# 106                        (100, 100, 100)                         1
# 107                             (100, 100)                         1
#
#     param_mlpregressor__solver param_mlpregressor__batch_size  \
# 60                       lbfgs                             64
# 61                       lbfgs                           auto
# 62                       lbfgs                             64
# 63                       lbfgs                           auto
# 64                       lbfgs                             32
# 65                       lbfgs                             64
# 66                       lbfgs                           auto
# 67                       lbfgs                             32
# 68                         sgd                           auto
# 69                       lbfgs                             32
# 70                       lbfgs                           auto
# 71                       lbfgs                             64
# 72                        adam                             64
# 73                        adam                             32
# 74                         sgd                             64
# 75                        adam                           auto
# 76                        adam                           auto
# 77                        adam                             64
# 78                        adam                           auto
# 79                        adam                             64
# 80                        adam                             64
# 81                         sgd                             32
# 82                        adam                             32
# 83                        adam                           auto
# 84                        adam                             64
# 85                        adam                           auto
# 86                        adam                           auto
# 87                        adam                           auto
# 88                        adam                             32
# 89                        adam                           auto
# 90                        adam                           auto
# 91                        adam                             64
# 92                         sgd                             32
# 93                        adam                             32
# 94                        adam                             32
# 95                        adam                             64
# 96                        adam                           auto
# 97                         sgd                             32
# 98                        adam                             32
# 99                         sgd                             32
# 100                       adam                             64
# 101                       adam                             32
# 102                       adam                             64
# 103                       adam                             64
# 104                       adam                             32
# 105                       adam                             32
# 106                       adam                             32
# 107                       adam                             32
#
#      mean_test_score converted_mean_fit_time
# 60         -0.033723                 8m, 12s
# 61         -0.033723                 9m, 42s
# 62         -0.033884                 8m, 47s
# 63         -0.033884                 8m, 58s
# 64         -0.033884                 8m, 15s
# 65         -0.033898                 8m, 56s
# 66         -0.033898                 9m, 32s
# 67         -0.033898                 8m, 25s
# 68         -0.033908                  7m, 3s
# 69         -0.034048                 8m, 29s
# 70         -0.034048                 9m, 23s
# 71         -0.034048                 8m, 43s
# 72         -0.034268                 4m, 13s
# 73         -0.034320                25m, 46s
# 74         -0.034389                 6m, 23s
# 75         -0.034551                 2m, 54s
# 76         -0.034747                 7m, 43s
# 77         -0.034827                 9m, 32s
# 78         -0.034863                 4m, 56s
# 79         -0.034896                 4m, 40s
# 80         -0.034929                 3m, 39s
# 81         -0.034957                 9m, 58s
# 82         -0.035083                12m, 57s
# 83         -0.035168                 9m, 45s
# 84         -0.035241                16m, 34s
# 85         -0.035282                  6m, 9s
# 86         -0.035455                 3m, 10s
# 87         -0.035501                 4m, 45s
# 88         -0.035605                 6m, 29s
# 89         -0.035722                 3m, 29s
# 90         -0.035798                 4m, 25s
# 91         -0.036111                 4m, 51s
# 92         -0.036171                17m, 17s
# 93         -0.036172                 9m, 35s
# 94         -0.036296                11m, 34s
# 95         -0.036720                 5m, 31s
# 96         -0.036906                 2m, 34s
# 97         -0.037063                  7m, 0s
# 98         -0.037406                14m, 11s
# 99         -0.037865                11m, 15s
# 100        -0.038052                 5m, 29s
# 101        -0.038060                10m, 50s
# 102        -0.038175                 5m, 21s
# 103        -0.039365                 6m, 30s
# 104        -0.040172                 6m, 50s
# 105        -0.040868                  8m, 0s
# 106        -0.041676                16m, 14s
# 107        -0.042397                 6m, 54s
